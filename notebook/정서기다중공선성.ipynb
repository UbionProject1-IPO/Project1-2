# %%
import pandas as pd
multi = pd.read_csv('../data/주가수익률/주가수익률_base.csv')

# %%
multi.columns.to_list()
# Out:
# ['1~5일 수익률 표준편차',
#  '6~10일 수익률 표준편차',
#  '11~15일 수익률 표준편차',
#  '16~20일 수익률 표준편차',
#  'kospi200(-20)',
#  'nasdaq(-20)',
#  'putcall(-20)',
#  'VIXCLS',
#  '미국10년물국채금리수익률(-20)',
#  '시장금리국고채3년',
#  '환율변동률(-20)',
#  '코스피변동률(-20)',
#  '코스닥변동률(-20)',
#  '런던_가스오일(-1~-5)',
#  '런던_가스오일(-6~-10)',
#  '런던_가스오일(-11~-15)',
#  '런던_가스오일(-16~-20)',
#  '난방유(-1~-5)',
#  '난방유(-6~-10)',
#  '난방유(-11~-15)',
#  '난방유(-16~-20)',
#  '탄소배출권(-1~-5)',
#  '탄소배출권(-6~-10)',
#  '탄소배출권(-11~-15)',
#  '탄소배출권(-16~-20)',
#  '브렌트유(-1~-5)',
#  '브렌트유(-6~-10)',
#  '브렌트유(-11~-15)',
#  '브렌트유(-16~-20)',
#  '가솔린(-1~-5)',
#  '가솔린(-6~-10)',
#  '가솔린(-11~-15)',
#  '가솔린(-16~-20)',
#  '천연가스(-1~-5)',
#  '천연가스(-6~-10)',
#  '천연가스(-11~-15)',
#  '천연가스(-16~-20)',
#  'WTI유(-1~-5)',
#  'WTI유(-6~-10)',
#  'WTI유(-11~-15)',
#  'WTI유(-16~-20)',
#  '금(-1~-5)',
#  '금(-6~-10)',
#  '금(-11~-15)',
#  '금(-16~-20)',
#  '은(-1~-5)',
#  '은(-6~-10)',
#  '은(-11~-15)',
#  '은(-16~-20)',
#  '백금(-1~-5)',
#  '백금(-6~-10)',
#  '백금(-11~-15)',
#  '백금(-16~-20)',
#  '주석(-1~-5)',
#  '주석(-6~-10)',
#  '주석(-11~-15)',
#  '주석(-16~-20)',
#  '납(-1~-5)',
#  '납(-6~-10)',
#  '납(-11~-15)',
#  '납(-16~-20)',
#  '아연(-1~-5)',
#  '아연(-6~-10)',
#  '아연(-11~-15)',
#  '아연(-16~-20)',
#  '알루미늄(-1~-5)',
#  '알루미늄(-6~-10)',
#  '알루미늄(-11~-15)',
#  '알루미늄(-16~-20)',
#  '니켈(-1~-5)',
#  '니켈(-6~-10)',
#  '니켈(-11~-15)',
#  '니켈(-16~-20)',
#  '구리_영국(-1~-5)',
#  '구리_영국(-6~-10)',
#  '구리_영국(-11~-15)',
#  '구리_영국(-16~-20)',
#  '구리_미국(-1~-5)',
#  '구리_미국(-6~-10)',
#  '구리_미국(-11~-15)',
#  '구리_미국(-16~-20)',
#  '미국_커피(-1~-5)',
#  '미국_커피(-6~-10)',
#  '미국_커피(-11~-15)',
#  '미국_커피(-16~-20)',
#  '미국_원면(-1~-5)',
#  '미국_원면(-6~-10)',
#  '미국_원면(-11~-15)',
#  '미국_원면(-16~-20)',
#  '현미(-1~-5)',
#  '현미(-6~-10)',
#  '현미(-11~-15)',
#  '현미(-16~-20)',
#  '돈육(-1~-5)',
#  '돈육(-6~-10)',
#  '돈육(-11~-15)',
#  '돈육(-16~-20)',
#  '미국_옥수수(-1~-5)',
#  '미국_옥수수(-6~-10)',
#  '미국_옥수수(-11~-15)',
#  '미국_옥수수(-16~-20)',
#  '런던_소맥(-1~-5)',
#  '런던_소맥(-6~-10)',
#  '런던_소맥(-11~-15)',
#  '런던_소맥(-16~-20)',
#  '미국_소맥(-1~-5)',
#  '미국_소맥(-6~-10)',
#  '미국_소맥(-11~-15)',
#  '미국_소맥(-16~-20)',
#  '오렌지주스(-1~-5)',
#  '오렌지주스(-6~-10)',
#  '오렌지주스(-11~-15)',
#  '오렌지주스(-16~-20)',
#  '원목(-1~-5)',
#  '원목(-6~-10)',
#  '원목(-11~-15)',
#  '원목(-16~-20)',
#  '미국_대두유(-1~-5)',
#  '미국_대두유(-6~-10)',
#  '미국_대두유(-11~-15)',
#  '미국_대두유(-16~-20)',
#  '미국_설탕(-1~-5)',
#  '미국_설탕(-6~-10)',
#  '미국_설탕(-11~-15)',
#  '미국_설탕(-16~-20)',
#  '미국_대두박(-1~-5)',
#  '미국_대두박(-6~-10)',
#  '미국_대두박(-11~-15)',
#  '미국_대두박(-16~-20)',
#  '생우(-1~-5)',
#  '생우(-6~-10)',
#  '생우(-11~-15)',
#  '생우(-16~-20)',
#  '런던_커피(-1~-5)',
#  '런던_커피(-6~-10)',
#  '런던_커피(-11~-15)',
#  '런던_커피(-16~-20)',
#  '런던_설탕(-1~-5)',
#  '런던_설탕(-6~-10)',
#  '런던_설탕(-11~-15)',
#  '런던_설탕(-16~-20)',
#  '귀리(-1~-5)',
#  '귀리(-6~-10)',
#  '귀리(-11~-15)',
#  '귀리(-16~-20)',
#  '런던 코코아 선물 과거 데이터(-1~-5)',
#  '런던 코코아 선물 과거 데이터(-6~-10)',
#  '런던 코코아 선물 과거 데이터(-11~-15)',
#  '런던 코코아 선물 과거 데이터(-16~-20)',
#  '육우(-1~-5)',
#  '육우(-6~-10)',
#  '육우(-11~-15)',
#  '육우(-16~-20)',
#  '미국_대두(-1~-5)',
#  '미국_대두(-6~-10)',
#  '미국_대두(-11~-15)',
#  '미국_대두(-16~-20)',
#  '코스닥수익률표준편차(-1~-5)',
#  '코스닥수익률표준편차(-6~-10)',
#  '코스닥수익률표준편차(-11~-15)',
#  '코스닥수익률표준편차(-16~-20)',
#  '코스피수익률표준편차(-1~-5)',
#  '코스피수익률표준편차(-6~-10)',
#  '코스피수익률표준편차(-11~-15)',
#  '코스피수익률표준편차(-16~-20)',
#  '나스닥수익률표준편차(-1~-5)',
#  '나스닥수익률표준편차(-6~-10)',
#  '나스닥수익률표준편차(-11~-15)',
#  '나스닥수익률표준편차(-16~-20)',
#  '원달러환율수익률표준편차(-1~-5)',
#  '원달러환율수익률표준편차(-6~-10)',
#  '원달러환율수익률표준편차(-11~-15)',
#  '원달러환율수익률표준편차(-16~-20)',
#  '회사명',
#  '경기국면',
#  '경기국면_encoded',
#  'cluster']

# %%
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager

# 1) 윈도우 폰트 경로 지정 (맑은 고딕)
font_path = r"C:\Windows\Fonts\malgun.ttf"

# 2) 폰트 프로퍼티 읽어오기
font_prop = font_manager.FontProperties(fname=font_path)
font_name = font_prop.get_name()

# 3) Matplotlib 전역 설정
matplotlib.rc('font', family=font_name)           # 기본 폰트 지정
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지

import warnings
warnings.filterwarnings('ignore')

# %%
multi.head()
# Out:
#    1~5일 수익률 표준편차  6~10일 수익률 표준편차  11~15일 수익률 표준편차  16~20일 수익률 표준편차  \
# 0       0.089380        0.064986         0.029926         0.042214
# 1       0.055183        0.027244         0.010927         0.014312
# 2       0.494998        0.054747         0.020483         0.047155
# 3       0.358088        0.053057         0.021488         0.044340
# 4       0.207570        0.075022         0.079149         0.022592
#
#    stock_code         상장일  kospi200(-20)  nasdaq(-20)  putcall(-20)  VIXCLS  \
# 0       95570  2015-08-21       0.136329    -0.041492      0.070588   28.03
# 1      211270  2016-03-04      -0.176910     0.043876      0.194915   16.86
# 2      241520  2016-12-19      -0.212121     0.021733     -0.145455   11.71
# 3      245620  2018-06-26       0.238400     0.018308     -0.010101   15.92
# 4      900290  2016-10-25       0.009464     0.000777     -0.099237   13.46
#
#    ...  코스피수익률표준편차(-16~-20)  나스닥수익률표준편차(-1~-5)  나스닥수익률표준편차(-6~-10)  \
# 0  ...             0.003992           0.014051            0.008737
# 1  ...             0.009830           0.013665            0.011253
# 2  ...             0.006622           0.006623            0.003389
# 3  ...             0.011118           0.010323            0.004575
# 4  ...             0.008561           0.004810            0.006153
#
#    나스닥수익률표준편차(-11~-15)  나스닥수익률표준편차(-16~-20)  원달러환율수익률표준편차(-1~-5)  \
# 0             0.008365             0.009260             0.002574
# 1             0.015439             0.015172             0.005941
# 2             0.006862             0.004424             0.006925
# 3             0.005181             0.008361             0.003369
# 4             0.004503             0.007630             0.007525
#
#    원달러환율수익률표준편차(-6~-10)  원달러환율수익률표준편차(-11~-15)  원달러환율수익률표준편차(-16~-20)  \
# 0              0.010154               0.005532               0.004754
# 1              0.006077               0.001593               0.007845
# 2              0.006202               0.006880               0.007359
# 3              0.003667               0.003788               0.008158
# 4              0.008725               0.004943               0.007877
#
#          회사명
# 0     AJ네트웍스
# 1     AP위성통신
# 2  DSC인베스트먼트
# 3       EDGC
# 4        GRT
#
# [5 rows x 176 columns]

# %%
multi.columns.to_list()
# Out:
# ['1~5일 수익률 표준편차',
#  '6~10일 수익률 표준편차',
#  '11~15일 수익률 표준편차',
#  '16~20일 수익률 표준편차',
#  'stock_code',
#  '상장일',
#  'kospi200(-20)',
#  'nasdaq(-20)',
#  'putcall(-20)',
#  'VIXCLS',
#  '미국10년물국채금리수익률(-20)',
#  '시장금리국고채3년',
#  '환율변동률(-20)',
#  '코스피변동률(-20)',
#  '코스닥변동률(-20)',
#  '런던_가스오일(-1~-5)',
#  '런던_가스오일(-6~-10)',
#  '런던_가스오일(-11~-15)',
#  '런던_가스오일(-16~-20)',
#  '난방유(-1~-5)',
#  '난방유(-6~-10)',
#  '난방유(-11~-15)',
#  '난방유(-16~-20)',
#  '탄소배출권(-1~-5)',
#  '탄소배출권(-6~-10)',
#  '탄소배출권(-11~-15)',
#  '탄소배출권(-16~-20)',
#  '브렌트유(-1~-5)',
#  '브렌트유(-6~-10)',
#  '브렌트유(-11~-15)',
#  '브렌트유(-16~-20)',
#  '가솔린(-1~-5)',
#  '가솔린(-6~-10)',
#  '가솔린(-11~-15)',
#  '가솔린(-16~-20)',
#  '천연가스(-1~-5)',
#  '천연가스(-6~-10)',
#  '천연가스(-11~-15)',
#  '천연가스(-16~-20)',
#  'WTI유(-1~-5)',
#  'WTI유(-6~-10)',
#  'WTI유(-11~-15)',
#  'WTI유(-16~-20)',
#  '금(-1~-5)',
#  '금(-6~-10)',
#  '금(-11~-15)',
#  '금(-16~-20)',
#  '은(-1~-5)',
#  '은(-6~-10)',
#  '은(-11~-15)',
#  '은(-16~-20)',
#  '백금(-1~-5)',
#  '백금(-6~-10)',
#  '백금(-11~-15)',
#  '백금(-16~-20)',
#  '주석(-1~-5)',
#  '주석(-6~-10)',
#  '주석(-11~-15)',
#  '주석(-16~-20)',
#  '납(-1~-5)',
#  '납(-6~-10)',
#  '납(-11~-15)',
#  '납(-16~-20)',
#  '아연(-1~-5)',
#  '아연(-6~-10)',
#  '아연(-11~-15)',
#  '아연(-16~-20)',
#  '알루미늄(-1~-5)',
#  '알루미늄(-6~-10)',
#  '알루미늄(-11~-15)',
#  '알루미늄(-16~-20)',
#  '니켈(-1~-5)',
#  '니켈(-6~-10)',
#  '니켈(-11~-15)',
#  '니켈(-16~-20)',
#  '구리_영국(-1~-5)',
#  '구리_영국(-6~-10)',
#  '구리_영국(-11~-15)',
#  '구리_영국(-16~-20)',
#  '구리_미국(-1~-5)',
#  '구리_미국(-6~-10)',
#  '구리_미국(-11~-15)',
#  '구리_미국(-16~-20)',
#  '미국_커피(-1~-5)',
#  '미국_커피(-6~-10)',
#  '미국_커피(-11~-15)',
#  '미국_커피(-16~-20)',
#  '미국_원면(-1~-5)',
#  '미국_원면(-6~-10)',
#  '미국_원면(-11~-15)',
#  '미국_원면(-16~-20)',
#  '현미(-1~-5)',
#  '현미(-6~-10)',
#  '현미(-11~-15)',
#  '현미(-16~-20)',
#  '돈육(-1~-5)',
#  '돈육(-6~-10)',
#  '돈육(-11~-15)',
#  '돈육(-16~-20)',
#  '미국_옥수수(-1~-5)',
#  '미국_옥수수(-6~-10)',
#  '미국_옥수수(-11~-15)',
#  '미국_옥수수(-16~-20)',
#  '런던_소맥(-1~-5)',
#  '런던_소맥(-6~-10)',
#  '런던_소맥(-11~-15)',
#  '런던_소맥(-16~-20)',
#  '미국_소맥(-1~-5)',
#  '미국_소맥(-6~-10)',
#  '미국_소맥(-11~-15)',
#  '미국_소맥(-16~-20)',
#  '오렌지주스(-1~-5)',
#  '오렌지주스(-6~-10)',
#  '오렌지주스(-11~-15)',
#  '오렌지주스(-16~-20)',
#  '원목(-1~-5)',
#  '원목(-6~-10)',
#  '원목(-11~-15)',
#  '원목(-16~-20)',
#  '미국_대두유(-1~-5)',
#  '미국_대두유(-6~-10)',
#  '미국_대두유(-11~-15)',
#  '미국_대두유(-16~-20)',
#  '미국_설탕(-1~-5)',
#  '미국_설탕(-6~-10)',
#  '미국_설탕(-11~-15)',
#  '미국_설탕(-16~-20)',
#  '미국_대두박(-1~-5)',
#  '미국_대두박(-6~-10)',
#  '미국_대두박(-11~-15)',
#  '미국_대두박(-16~-20)',
#  '생우(-1~-5)',
#  '생우(-6~-10)',
#  '생우(-11~-15)',
#  '생우(-16~-20)',
#  '런던_커피(-1~-5)',
#  '런던_커피(-6~-10)',
#  '런던_커피(-11~-15)',
#  '런던_커피(-16~-20)',
#  '런던_설탕(-1~-5)',
#  '런던_설탕(-6~-10)',
#  '런던_설탕(-11~-15)',
#  '런던_설탕(-16~-20)',
#  '귀리(-1~-5)',
#  '귀리(-6~-10)',
#  '귀리(-11~-15)',
#  '귀리(-16~-20)',
#  '런던 코코아 선물 과거 데이터(-1~-5)',
#  '런던 코코아 선물 과거 데이터(-6~-10)',
#  '런던 코코아 선물 과거 데이터(-11~-15)',
#  '런던 코코아 선물 과거 데이터(-16~-20)',
#  '육우(-1~-5)',
#  '육우(-6~-10)',
#  '육우(-11~-15)',
#  '육우(-16~-20)',
#  '미국_대두(-1~-5)',
#  '미국_대두(-6~-10)',
#  '미국_대두(-11~-15)',
#  '미국_대두(-16~-20)',
#  '코스닥수익률표준편차(-1~-5)',
#  '코스닥수익률표준편차(-6~-10)',
#  '코스닥수익률표준편차(-11~-15)',
#  '코스닥수익률표준편차(-16~-20)',
#  '코스피수익률표준편차(-1~-5)',
#  '코스피수익률표준편차(-6~-10)',
#  '코스피수익률표준편차(-11~-15)',
#  '코스피수익률표준편차(-16~-20)',
#  '나스닥수익률표준편차(-1~-5)',
#  '나스닥수익률표준편차(-6~-10)',
#  '나스닥수익률표준편차(-11~-15)',
#  '나스닥수익률표준편차(-16~-20)',
#  '원달러환율수익률표준편차(-1~-5)',
#  '원달러환율수익률표준편차(-6~-10)',
#  '원달러환율수익률표준편차(-11~-15)',
#  '원달러환율수익률표준편차(-16~-20)',
#  '회사명']

# %%
multi = multi.drop(columns=['상장일','stock_code','회사명'])

# %% [markdown]
# ## 상관계수확인

# %%
# 상관계수 분포 파악하기

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# 1) 상관계수 행렬 계산
corr = multi.corr().abs()  # 절대값으로

# 2) upper triangle만 추출 (중복 제거)
corr_vals = corr.where(~np.eye(corr.shape[0],dtype=bool))
corr_vals = corr_vals.unstack().dropna()

# 3) 히스토그램으로 분포 확인
plt.figure(figsize=(8,4))
plt.hist(corr_vals, bins=50)
plt.xlabel('절대 상관계수')
plt.ylabel('빈도')
plt.title('변수쌍별 상관계수 분포')
plt.show()

# %%
#높은 상관쌍(Threshold)만 추출하기

import pandas as pd

# 1) 상관계수 행렬 계산
corr = multi.corr().abs()

# 2) 상삼각행렬 mask
mask = np.triu(np.ones_like(corr, dtype=bool), k=1)

# 3) 임계값 이상의 쌍 필터링
threshold = 0.6
high_corr = (
    corr.where(mask)
        .stack()
        .reset_index()
        .rename(columns={'level_0':'var1','level_1':'var2',0:'corr'})
)
high_corr = high_corr[high_corr['corr'] > threshold].sort_values('corr', ascending=False)

print(f"총 {len(high_corr)}개 쌍이 |r| > {threshold}")
high_corr.head(57)
# Out:
# 총 57개 쌍이 |r| > 0.6
#                             var1                 var2      corr
# 4011            브렌트유(-1~-5)         WTI유(-1~-5)  0.944801
# 4158           브렌트유(-6~-10)        WTI유(-6~-10)  0.926015
# 4304          브렌트유(-11~-15)       WTI유(-11~-15)  0.916532
# 10030        구리_영국(-6~-10)   구리_미국(-6~-10)  0.911842
# 10128       구리_영국(-11~-15)  구리_미국(-11~-15)  0.906678
# 4449          브렌트유(-16~-20)       WTI유(-16~-20)  0.901562
# 9931          구리_영국(-1~-5)    구리_미국(-1~-5)  0.887681
# 10225       구리_영국(-16~-20)  구리_미국(-16~-20)  0.877155
# 2795             난방유(-1~-5)     브렌트유(-1~-5)  0.842149
# 2950            난방유(-6~-10)    브렌트유(-6~-10)  0.833484
# 3104           난방유(-11~-15)   브렌트유(-11~-15)  0.831630
# 2807             난방유(-1~-5)         WTI유(-1~-5)  0.825403
# 3257           난방유(-16~-20)   브렌트유(-16~-20)  0.818862
# 2962            난방유(-6~-10)        WTI유(-6~-10)  0.813876
# 3269           난방유(-16~-20)       WTI유(-16~-20)  0.792540
# 3116           난방유(-11~-15)       WTI유(-11~-15)  0.786906
# 1837                 코스피변동률(-20)          코스닥변동률(-20)  0.782956
# 2320    런던_가스오일(-6~-10)     난방유(-6~-10)  0.759920
# 2478   런던_가스오일(-11~-15)    난방유(-11~-15)  0.754399
# 13870     미국_대두박(-11~-15)  미국_대두(-11~-15)  0.747554
# 2161     런던_가스오일(-1~-5)      난방유(-1~-5)  0.736539
# 6625                금(-16~-20)         은(-16~-20)  0.723001
# 6496                금(-11~-15)         은(-11~-15)  0.722529
# 1340                      VIXCLS    나스닥수익률표준편차(-1~-5)  0.721621
# 14790        코스닥수익률표준편차(-11~-15)  코스피수익률표준편차(-11~-15)  0.718066
# 14761          코스닥수익률표준편차(-1~-5)    코스피수익률표준편차(-1~-5)  0.716543
# 13824      미국_대두박(-6~-10)   미국_대두(-6~-10)  0.713769
# 4150           브렌트유(-6~-10)     가솔린(-6~-10)  0.712897
# 2954            난방유(-6~-10)     가솔린(-6~-10)  0.703001
# 4732            가솔린(-6~-10)        WTI유(-6~-10)  0.702735
# 13915     미국_대두박(-16~-20)  미국_대두(-16~-20)  0.700988
# 6366                 금(-6~-10)          은(-6~-10)  0.692936
# 4003            브렌트유(-1~-5)      가솔린(-1~-5)  0.690524
# 4589             가솔린(-1~-5)         WTI유(-1~-5)  0.680434
# 3261           난방유(-16~-20)    가솔린(-16~-20)  0.679579
# 5015           가솔린(-16~-20)       WTI유(-16~-20)  0.677920
# 4441          브렌트유(-16~-20)    가솔린(-16~-20)  0.677342
# 2169     런던_가스오일(-1~-5)     브렌트유(-1~-5)  0.675922
# 4296          브렌트유(-11~-15)    가솔린(-11~-15)  0.675410
# 3108           난방유(-11~-15)    가솔린(-11~-15)  0.673446
# 6235                  금(-1~-5)           은(-1~-5)  0.669720
# 2181     런던_가스오일(-1~-5)         WTI유(-1~-5)  0.654952
# 855                  nasdaq(-20)          코스피변동률(-20)  0.653294
# 2635   런던_가스오일(-16~-20)    난방유(-16~-20)  0.651117
# 2531   런던_가스오일(-11~-15)       니켈(-16~-20)  0.648543
# 2328    런던_가스오일(-6~-10)    브렌트유(-6~-10)  0.646049
# 14803        코스닥수익률표준편차(-16~-20)  코스피수익률표준편차(-16~-20)  0.644812
# 4874           가솔린(-11~-15)       WTI유(-11~-15)  0.643751
# 2799             난방유(-1~-5)      가솔린(-1~-5)  0.639796
# 2340    런던_가스오일(-6~-10)        WTI유(-6~-10)  0.627164
# 9524                니켈(-1~-5)       니켈(-16~-20)  0.616726
# 2655   런던_가스오일(-16~-20)       WTI유(-16~-20)  0.614986
# 6753                  은(-1~-5)        백금(-1~-5)  0.610196
# 2643   런던_가스오일(-16~-20)   브렌트유(-16~-20)  0.610192
# 856                  nasdaq(-20)          코스닥변동률(-20)  0.603848
# 2486   런던_가스오일(-11~-15)   브렌트유(-11~-15)  0.602932
# 14776         코스닥수익률표준편차(-6~-10)   코스피수익률표준편차(-6~-10)  0.600730

# %%
# 계층적 군집 (Clustermap)으로 히트맵 그리기

import seaborn as sns
import matplotlib.pyplot as plt

# 변수 표준화 (선택)
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(multi)

# clustermap 그리기
sns.clustermap(
    pd.DataFrame(X_std, columns=multi.columns).corr(),
    method='average',      # linkage 방법
    metric='euclidean',    # 거리 측정
    cmap='vlag',
    figsize=(12,12),
    vmax=1, vmin=-1,
    linewidths=.5
)
plt.suptitle('Hierarchical Clustering of Variable Correlations', y=1.02)
plt.show()

# %%
# PCA 로딩(Loading) 분석으로 군집 확인

import numpy as np
from sklearn.decomposition import PCA

# 1) 표준화
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(multi)

# 2) PCA 수행
pca = PCA(n_components=10)   # 상위 10개 주성분
pca.fit(X_std)

# 3) 로딩 행렬 (주성분 × 변수)
loadings = pd.DataFrame(
    pca.components_.T,
    index=multi.columns,
    columns=[f'PC{i+1}' for i in range(10)]
)

# 4) 특정 PC에서 절댓값 큰 상위 변수 보기
for pc in loadings.columns:
    top_vars = loadings[pc].abs().sort_values(ascending=False).head(5).index.tolist()
    print(f"{pc} 상위 5개 로딩 변수: {top_vars}")
# Out:
# PC1 상위 5개 로딩 변수: ['런던_가스오일(-6~-10)', '나스닥수익률표준편차(-6~-10)', '나스닥수익률표준편차(-11~-15)', '난방유(-6~-10)', '런던_가스오일(-11~-15)']
# PC2 상위 5개 로딩 변수: ['미국_옥수수(-16~-20)', 'VIXCLS', '런던_소맥(-16~-20)', 'WTI유(-1~-5)', 'nasdaq(-20)']
# PC3 상위 5개 로딩 변수: ['브렌트유(-11~-15)', 'WTI유(-11~-15)', '난방유(-11~-15)', '브렌트유(-16~-20)', 'WTI유(-16~-20)']
# PC4 상위 5개 로딩 변수: ['미국_옥수수(-1~-5)', '코스피변동률(-20)', '미국_대두(-1~-5)', '미국_대두(-6~-10)', '구리_영국(-11~-15)']
# PC5 상위 5개 로딩 변수: ['kospi200(-20)', '미국_대두(-11~-15)', '미국_옥수수(-11~-15)', '아연(-6~-10)', '미국_대두박(-11~-15)']
# PC6 상위 5개 로딩 변수: ['코스피변동률(-20)', '코스닥변동률(-20)', 'nasdaq(-20)', '원달러환율수익률표준편차(-6~-10)', '시장금리국고채3년']
# PC7 상위 5개 로딩 변수: ['금(-6~-10)', '미국_옥수수(-6~-10)', '백금(-6~-10)', '은(-6~-10)', '브렌트유(-16~-20)']
# PC8 상위 5개 로딩 변수: ['구리_영국(-1~-5)', '금(-16~-20)', '은(-16~-20)', '구리_미국(-1~-5)', '금(-1~-5)']
# PC9 상위 5개 로딩 변수: ['미국_커피(-11~-15)', '미국_설탕(-1~-5)', '금(-1~-5)', '은(-1~-5)', '브렌트유(-1~-5)']
# PC10 상위 5개 로딩 변수: ['니켈(-1~-5)', '니켈(-16~-20)', '알루미늄(-1~-5)', '아연(-6~-10)', '미국10년물국채금리수익률(-20)']

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler


# 3) 독립변수 행렬(X) 준비 및 표준화
#    보통 VIF 계산 전 스케일링은 선택 사항이지만, 값 차이가 클 때는 권장됩니다.
scaler = StandardScaler()
X_scaled = scaler.fit_transform(multi.values)
X = pd.DataFrame(X_scaled, columns=multi.columns)

# 4) VIF 계산
vif_data = pd.DataFrame({
    'variable': X.columns,
    'VIF': [variance_inflation_factor(X.values, i)
            for i in range(X.shape[1])]
})

# 5) 높은 VIF 순으로 정렬·확인
vif_data = vif_data.sort_values('VIF', ascending=False).reset_index(drop=True)
print(vif_data.head(20))

# 6) 임계값(예: VIF>10) 이상인 변수만 필터링
high_vif = vif_data[vif_data['VIF'] > 10]
print(f"\nVIF > 10인 변수 개수: {len(high_vif)}")
print(high_vif)
# Out:
#                 variable        VIF
# 0       브렌트유(-1~-5)  21.849589
# 1           WTI유(-1~-5)  17.927866
# 2     브렌트유(-11~-15)  17.355823
# 3      브렌트유(-6~-10)  16.650113
# 4     브렌트유(-16~-20)  15.609989
# 5          WTI유(-6~-10)  14.560224
# 6    구리_영국(-6~-10)  13.729718
# 7      난방유(-11~-15)  13.707159
# 8         WTI유(-11~-15)  13.698702
# 9   구리_영국(-11~-15)  13.402172
# 10    구리_미국(-6~-10)  13.231220
# 11      난방유(-6~-10)  12.894454
# 12   구리_미국(-11~-15)  12.437398
# 13        WTI유(-16~-20)  12.147137
# 14       난방유(-1~-5)  11.296411
# 15  구리_영국(-16~-20)  10.823400
# 16   구리_미국(-16~-20)  10.204184
# 17    구리_영국(-1~-5)   9.990508
# 18     구리_미국(-1~-5)   9.645193
# 19     난방유(-16~-20)   8.547928
#
# VIF > 10인 변수 개수: 17
#                 variable        VIF
# 0       브렌트유(-1~-5)  21.849589
# 1           WTI유(-1~-5)  17.927866
# 2     브렌트유(-11~-15)  17.355823
# 3      브렌트유(-6~-10)  16.650113
# 4     브렌트유(-16~-20)  15.609989
# 5          WTI유(-6~-10)  14.560224
# 6    구리_영국(-6~-10)  13.729718
# 7      난방유(-11~-15)  13.707159
# 8         WTI유(-11~-15)  13.698702
# 9   구리_영국(-11~-15)  13.402172
# 10    구리_미국(-6~-10)  13.231220
# 11      난방유(-6~-10)  12.894454
# 12   구리_미국(-11~-15)  12.437398
# 13        WTI유(-16~-20)  12.147137
# 14       난방유(-1~-5)  11.296411
# 15  구리_영국(-16~-20)  10.823400
# 16   구리_미국(-16~-20)  10.204184

# %%
import scipy.cluster.hierarchy as sch

corr = X.corr().abs()
dist = 1 - corr
link = sch.linkage(sch.distance.squareform(dist), method='average')
clusters = sch.fcluster(link, t=1.0, criterion='distance')

# clusters가 같은 변수끼리 군집, 각 군집에서 하나씩 선택

# %% [markdown]
# ## PCA 비지도학습

# %%
sm = pd.read_csv('../data/주가수익률/주가수익률_동행순환변동치_smooth.csv')
sm = sm[['회사명','경기국면']]
sm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 533 entries, 0 to 532
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     533 non-null    object
#  1   경기국면    533 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.5+ KB

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# 1) 데이터 불러오기 및 전처리
multi = pd.read_csv('../data/주가수익률/주가수익률_base.csv')
multi = multi.drop(columns=['상장일','stock_code','회사명']).dropna().reset_index(drop=True)

# 2) 표준화
X_std = StandardScaler().fit_transform(multi.values)

# 3) PCA – 설명 분산 80% 확보
pca_full = PCA().fit(X_std)
cum_var = np.cumsum(pca_full.explained_variance_ratio_)
n_comp = np.searchsorted(cum_var, 0.8) + 1
print(f"80% 설명분산 확보를 위한 PC 개수: {n_comp}")

pca = PCA(n_components=n_comp, random_state=42)
X_pca = pca.fit_transform(X_std)

# 4) 최적 k 탐색 (실루엣 스코어)
sil_scores = []
ks = list(range(2, 11))
for k in ks:
    km = KMeans(n_clusters=k, random_state=42).fit(X_pca)
    sil_scores.append(silhouette_score(X_pca, km.labels_))

plt.figure(figsize=(6,4))
plt.plot(ks, sil_scores, marker='o')
plt.xlabel('Number of clusters k')
plt.ylabel('Silhouette Score')
plt.title('KMeans Silhouette Analysis')
plt.grid(True)
plt.show()

best_k = ks[np.argmax(sil_scores)]
print(f"최적의 k (실루엣 기준): {best_k}")

# 5) 여러 알고리즘 비교
algos = {
    'KMeans':        KMeans(n_clusters=best_k, random_state=42).fit_predict(X_pca),
    'Agglomerative': AgglomerativeClustering(n_clusters=best_k).fit_predict(X_pca),
    'DBSCAN':        DBSCAN(eps=1.0, min_samples=5).fit_predict(X_pca),
    'GMM':           GaussianMixture(n_components=best_k, random_state=42).fit_predict(X_pca)
}

for name, labels in algos.items():
    uniq = set(labels)
    if len(uniq) > 1 and -1 not in uniq:
        score = silhouette_score(X_pca, labels)
        print(f"{name}: clusters={len(uniq)}, silhouette={score:.3f}")
    else:
        print(f"{name}: clusters={len(uniq)}")

# 6) 최종 클러스터링 (예: KMeans)
multi_pca = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(n_comp)])
multi_pca['cluster'] = algos['KMeans']

# 7) 각 클러스터 프로파일링 (원본 변수 평균)
profile = multi.join(multi_pca['cluster']).groupby('cluster').mean()
print(profile)

# 8) 각 PC별 “주요 기여 변수” 확인
loadings = pd.DataFrame(
    pca.components_.T,
    index=multi.columns,
    columns=[f'PC{i+1}' for i in range(n_comp)]
)
pc_top_vars = {
    pc: loadings[pc].abs().sort_values(ascending=False).head(10).index.tolist()
    for pc in loadings.columns
}
for pc, vars_ in pc_top_vars.items():
    print(f"{pc} 상위 기여 변수: {vars_}")

# ───────────────────────────────────────────────────────
# 9) Random Forest로 cluster 예측 및 성능 평가
#    (원본 176개 변수 → cluster 레이블)

# 9.1) 데이터 준비
df_rf = multi.copy()
df_rf['cluster'] = multi_pca['cluster']

X = df_rf.drop(columns=['cluster'])
y = df_rf['cluster']

# 9.2) train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# 9.3) RF 학습
rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train, y_train)

# 9.4) 피처 임포턴스 시각화
importances = pd.Series(rf.feature_importances_, index=X.columns).sort_values(ascending=False)
plt.figure(figsize=(8,6))
importances.head(20).plot.barh()
plt.gca().invert_yaxis()
plt.xlabel('Feature Importance')
plt.title('Top 20 Feature Importances (RF)')
plt.tight_layout()
plt.show()

print("Top 20 important features:")
print(importances.head(20))

# 9.5) 예측 및 혼동행렬 출력
y_pred = rf.predict(X_test)

# classification report
print("Classification Report:\n")
print(classification_report(y_test, y_pred))

# confusion matrix 시각화
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
fig, ax = plt.subplots(figsize=(6,6))
disp.plot(ax=ax, cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 80% 설명분산 확보를 위한 PC 개수: 62
# 최적의 k (실루엣 기준): 2
# KMeans: clusters=2, silhouette=0.284
# Agglomerative: clusters=2, silhouette=0.284
# DBSCAN: clusters=1
# GMM: clusters=2, silhouette=0.284
#          1~5일 수익률 표준편차  6~10일 수익률 표준편차  11~15일 수익률 표준편차  16~20일 수익률 표준편차  \
# cluster
# 0             0.241906        0.051096         0.042448         0.043041
# 1             0.196264        0.046266         0.038988         0.045988
#
#          kospi200(-20)  nasdaq(-20)  putcall(-20)     VIXCLS  \
# cluster
# 0             0.025453     0.014323      0.011352  17.918176
# 1             0.091008    -0.013097      0.019654  28.000714
#
#          미국10년물국채금리수익률(-20)  시장금리국고채3년  환율변동률(-20)  코스피변동률(-20)  코스닥변동률(-20)  \
# cluster
# 0                  0.020505   1.669851    0.001181     0.003123    -0.000574
# 1                  0.025280   3.330714    0.006049    -0.015015    -0.024912
#
#          런던_가스오일(-1~-5)  런던_가스오일(-6~-10)  \
# cluster
# 0                       0.013588                  0.015709
# 1                       0.029653                  0.033858
#
#          런던_가스오일(-11~-15)  런던_가스오일(-16~-20)  \
# cluster
# 0                         0.014389                   0.013266
# 1                         0.033058                   0.026507
#
#          난방유(-1~-5)  난방유(-6~-10)  난방유(-11~-15)  \
# cluster
# 0               0.013466          0.015014           0.014357
# 1               0.026056          0.027137           0.023219
#
#          난방유(-16~-20)  탄소배출권(-1~-5)  탄소배출권(-6~-10)  \
# cluster
# 0                 0.013797              0.018369               0.020350
# 1                 0.022065              0.023984               0.025525
#
#          탄소배출권(-11~-15)  탄소배출권(-16~-20)  브렌트유(-1~-5)  \
# cluster
# 0                      0.019385                0.017887          0.014653
# 1                      0.021757                0.022942          0.023961
#
#          브렌트유(-6~-10)  브렌트유(-11~-15)  브렌트유(-16~-20)  \
# cluster
# 0                 0.016432            0.015291            0.015117
# 1                 0.026887            0.019395            0.020729
#
#          가솔린(-1~-5)  가솔린(-6~-10)  가솔린(-11~-15)  \
# cluster
# 0               0.015919          0.016958           0.015962
# 1               0.025033          0.027324           0.022256
#
#          가솔린(-16~-20)  천연가스(-1~-5)  천연가스(-6~-10)  \
# cluster
# 0                 0.016029           0.023922            0.025766
# 1                 0.022698           0.037004            0.043699
#
#          천연가스(-11~-15)  천연가스(-16~-20)  WTI유(-1~-5)  \
# cluster
# 0                   0.022591             0.021848      0.015949
# 1                   0.040917             0.036081      0.026595
#
#          WTI유(-6~-10)  WTI유(-11~-15)  WTI유(-16~-20)  금(-1~-5)  \
# cluster
# 0             0.017687        0.016478        0.015487    0.005966
# 1             0.029738        0.022435        0.024177    0.007934
#
#          금(-6~-10)  금(-11~-15)  금(-16~-20)  은(-1~-5)  은(-6~-10)  \
# cluster
# 0           0.006505      0.006604      0.005895    0.011119     0.012108
# 1           0.008525      0.008919      0.007240    0.017701     0.016133
#
#          은(-11~-15)  은(-16~-20)  백금(-1~-5)  백금(-6~-10)  \
# cluster
# 0            0.011817      0.010795       0.010772        0.012054
# 1            0.017386      0.015475       0.016954        0.018666
#
#          백금(-11~-15)  백금(-16~-20)  주석(-1~-5)  주석(-6~-10)  \
# cluster
# 0               0.011110         0.010937      0.008324       0.009868
# 1               0.017223         0.015122      0.018281       0.020310
#
#          주석(-11~-15)  주석(-16~-20)  납(-1~-5)  납(-6~-10)  \
# cluster
# 0              0.008908        0.007965    0.010012     0.011006
# 1              0.018247        0.015401    0.012776     0.014607
#
#          납(-11~-15)  납(-16~-20)  아연(-1~-5)  아연(-6~-10)  \
# cluster
# 0            0.010456      0.009887      0.010653       0.012205
# 1            0.014469      0.013282      0.016316       0.016541
#
#          아연(-11~-15)  아연(-16~-20)  알루미늄(-1~-5)  \
# cluster
# 0              0.010922        0.010919           0.007659
# 1              0.016142        0.013456           0.015200
#
#          알루미늄(-6~-10)  알루미늄(-11~-15)  알루미늄(-16~-20)  \
# cluster
# 0                  0.008911             0.008520             0.007983
# 1                  0.017810             0.014983             0.014787
#
#          니켈(-1~-5)  니켈(-6~-10)  니켈(-11~-15)  니켈(-16~-20)  \
# cluster
# 0            0.012592       0.014681        0.014318        0.013309
# 1            0.035139       0.027986        0.027903        0.028993
#
#          구리_영국(-1~-5)  구리_영국(-6~-10)  구리_영국(-11~-15)  \
# cluster
# 0                  0.008415             0.009768              0.009029
# 1                  0.011494             0.013051              0.012472
#
#          구리_영국(-16~-20)  구리_미국(-1~-5)  구리_미국(-6~-10)  \
# cluster
# 0                    0.008702           0.009145            0.010472
# 1                    0.012972           0.013049            0.015198
#
#          구리_미국(-11~-15)  구리_미국(-16~-20)  미국_커피(-1~-5)  \
# cluster
# 0                   0.009964             0.009650           0.014134
# 1                   0.013907             0.013298           0.019506
#
#          미국_커피(-6~-10)  미국_커피(-11~-15)  미국_커피(-16~-20)  \
# cluster
# 0                  0.015799             0.014820             0.014208
# 1                  0.020748             0.018536             0.018079
#
#          미국_원면(-1~-5)  미국_원면(-6~-10)  미국_원면(-11~-15)  \
# cluster
# 0                   0.009866              0.011126               0.010470
# 1                   0.018467              0.022829               0.021868
#
#          미국_원면(-16~-20)  현미(-1~-5)  현미(-6~-10)  현미(-11~-15)  \
# cluster
# 0                      0.01016      0.008263       0.008669        0.008145
# 1                      0.02159      0.007657       0.009948        0.007024
#
#          현미(-16~-20)  돈육(-1~-5)  돈육(-6~-10)  돈육(-11~-15)  \
# cluster
# 0              0.008329       0.016108        0.019104         0.016790
# 1              0.008748       0.013466        0.015341         0.012536
#
#          돈육(-16~-20)  미국_옥수수(-1~-5)  미국_옥수수(-6~-10)  \
# cluster
# 0               0.014769              0.010567               0.011927
# 1               0.014178              0.013045               0.014686
#
#          미국_옥수수(-11~-15)  미국_옥수수(-16~-20)  런던_소맥(-1~-5)  \
# cluster
# 0                      0.011234                0.010226             0.007469
# 1                      0.013601                0.013225             0.014469
#
#          런던_소맥(-6~-10)  런던_소맥(-11~-15)  런던_소맥(-16~-20)  \
# cluster
# 0                    0.008138               0.007398               0.007220
# 1                    0.018057               0.014421               0.017864
#
#          미국_소맥(-1~-5)  미국_소맥(-6~-10)  미국_소맥(-11~-15)  \
# cluster
# 0                  0.012804             0.014649              0.013268
# 1                  0.022271             0.026088              0.020170
#
#          미국_소맥(-16~-20)  오렌지주스(-1~-5)  오렌지주스(-6~-10)  \
# cluster
# 0                    0.012532            0.013583             0.015246
# 1                    0.024612            0.022054             0.021215
#
#          오렌지주스(-11~-15)  오렌지주스(-16~-20)  원목(-1~-5)  \
# cluster
# 0                    0.013819              0.013406       0.019042
# 1                    0.018647              0.019724       0.024369
#
#          원목(-6~-10)  원목(-11~-15)  원목(-16~-20)  \
# cluster
# 0              0.021551         0.021089         0.018518
# 1              0.027511         0.021494         0.023600
#
#          미국_대두유(-1~-5)  미국_대두유(-6~-10)  미국_대두유(-11~-15)  \
# cluster
# 0                   0.009673              0.010988               0.010207
# 1                   0.017543              0.018918               0.015485
#
#          미국_대두유(-16~-20)  미국_설탕(-1~-5)  미국_설탕(-6~-10)  \
# cluster
# 0                     0.009891             0.012560              0.014109
# 1                     0.016625             0.011018              0.011270
#
#          미국_설탕(-11~-15)  미국_설탕(-16~-20)  미국_대두박(-1~-5)  \
# cluster
# 0                     0.013275               0.012783              0.009381
# 1                     0.011559               0.011235              0.012339
#
#          미국_대두박(-6~-10)  미국_대두박(-11~-15)  \
# cluster
# 0                     0.010935                0.009716
# 1                     0.014702                0.013784
#
#          미국_대두박(-16~-20)  생우(-1~-5)  생우(-6~-10)  생우(-11~-15)  \
# cluster
# 0                      0.008888      0.007367       0.008074        0.008037
# 1                      0.012177      0.006609       0.007173        0.006647
#
#          생우(-16~-20)  런던_커피(-1~-5)  런던_커피(-6~-10)  \
# cluster
# 0              0.007725            0.009680             0.011264
# 1              0.007195            0.009649             0.011721
#
#          런던_커피(-11~-15)  런던_커피(-16~-20)  런던_설탕(-1~-5)  \
# cluster
# 0                    0.010121              0.009546              0.010101
# 1                    0.009529              0.009184              0.011725
#
#          런던_설탕(-6~-10)  런던_설탕(-11~-15)  \
# cluster
# 0                     0.011961                0.011167
# 1                     0.013143                0.013918
#
#          런던_설탕(-16~-20)  귀리(-1~-5)  귀리(-6~-10)  귀리(-11~-15)  \
# cluster
# 0                      0.010134     0.013765      0.015373       0.015086
# 1                      0.010976     0.018737      0.022600       0.024243
#
#          귀리(-16~-20)  런던 코코아 선물 과거 데이터(-1~-5)  런던 코코아 선물 과거 데이터(-6~-10)  \
# cluster
# 0             0.014105                 0.010164                  0.011951
# 1             0.022239                 0.010799                  0.012073
#
#          런던 코코아 선물 과거 데이터(-11~-15)  런던 코코아 선물 과거 데이터(-16~-20)  육우(-1~-5)  \
# cluster
# 0                         0.010893                   0.009507      0.007415
# 1                         0.010589                   0.009298      0.008307
#
#          육우(-6~-10)  육우(-11~-15)  육우(-16~-20)  미국_대두(-1~-5)  \
# cluster
# 0             0.008557        0.008000        0.007403           0.008134
# 1             0.011048        0.008654        0.008708           0.013249
#
#          미국_대두(-6~-10)  미국_대두(-11~-15)  미국_대두(-16~-20)  \
# cluster
# 0                  0.009293             0.008462             0.008112
# 1                  0.013136             0.011834             0.012480
#
#          코스닥수익률표준편차(-1~-5)  코스닥수익률표준편차(-6~-10)  코스닥수익률표준편차(-11~-15)  \
# cluster
# 0                 0.011503            0.010956             0.011174
# 1                 0.017072            0.017423             0.017985
#
#          코스닥수익률표준편차(-16~-20)  코스피수익률표준편차(-1~-5)  코스피수익률표준편차(-6~-10)  \
# cluster
# 0                   0.011124           0.008147            0.007900
# 1                   0.018112           0.011688            0.011634
#
#          코스피수익률표준편차(-11~-15)  코스피수익률표준편차(-16~-20)  나스닥수익률표준편차(-1~-5)  \
# cluster
# 0                   0.008345             0.008397           0.010285
# 1                   0.011944             0.011978           0.022885
#
#          나스닥수익률표준편차(-6~-10)  나스닥수익률표준편차(-11~-15)  나스닥수익률표준편차(-16~-20)  \
# cluster
# 0                  0.010044             0.010114             0.010075
# 1                  0.020993             0.020620             0.018962
#
#          원달러환율수익률표준편차(-1~-5)  원달러환율수익률표준편차(-6~-10)  원달러환율수익률표준편차(-11~-15)  \
# cluster
# 0                   0.004747              0.004797               0.004847
# 1                   0.007241              0.006581               0.006654
#
#          원달러환율수익률표준편차(-16~-20)
# cluster
# 0                     0.004625
# 1                     0.006184
# PC1 상위 기여 변수: ['런던_가스오일(-6~-10)', '나스닥수익률표준편차(-6~-10)', '나스닥수익률표준편차(-11~-15)', '난방유(-6~-10)', '런던_가스오일(-11~-15)', '런던_가스오일(-1~-5)', '나스닥수익률표준편차(-1~-5)', '알루미늄(-6~-10)', 'VIXCLS', 'WTI유(-6~-10)']
# PC2 상위 기여 변수: ['미국_옥수수(-16~-20)', 'VIXCLS', '런던_소맥(-16~-20)', 'WTI유(-1~-5)', 'nasdaq(-20)', '미국_옥수수(-11~-15)', '브렌트유(-1~-5)', 'kospi200(-20)', '미국_대두(-11~-15)', '가솔린(-1~-5)']
# PC3 상위 기여 변수: ['브렌트유(-11~-15)', 'WTI유(-11~-15)', '난방유(-11~-15)', '브렌트유(-16~-20)', 'WTI유(-16~-20)', '가솔린(-11~-15)', '생우(-11~-15)', '난방유(-16~-20)', '생우(-6~-10)', '육우(-11~-15)']
# PC4 상위 기여 변수: ['미국_옥수수(-1~-5)', '코스피변동률(-20)', '미국_대두(-1~-5)', '미국_대두(-6~-10)', '구리_영국(-11~-15)', '런던_소맥(-1~-5)', '구리_미국(-11~-15)', '은(-11~-15)', '미국_소맥(-1~-5)', '런던_소맥(-6~-10)']
# PC55 상위 기여 변수: ['원달러환율수익률표준편차(-6~-10)', '원목(-6~-10)', '탄소배출권(-1~-5)', '미국_원면(-1~-5)', '미국_설탕(-1~-5)', '11~15일 수익률 표준편차', '원목(-16~-20)', '원목(-1~-5)', '미국_대두유(-16~-20)', '런던 코코아 선물 과거 데이터(-11~-15)']
# PC56 상위 기여 변수: ['니켈(-11~-15)', '주석(-16~-20)', '알루미늄(-16~-20)', '원달러환율수익률표준편차(-16~-20)', 'putcall(-20)', '니켈(-6~-10)', '천연가스(-6~-10)', '알루미늄(-11~-15)', '오렌지주스(-16~-20)', '육우(-16~-20)']
# PC57 상위 기여 변수: ['현미(-16~-20)', '런던 코코아 선물 과거 데이터(-16~-20)', '육우(-16~-20)', '오렌지주스(-11~-15)', '미국_대두유(-6~-10)', '납(-11~-15)', '미국_옥수수(-1~-5)', '미국_소맥(-6~-10)', '런던_가스오일(-16~-20)', '천연가스(-6~-10)']
# PC58 상위 기여 변수: ['육우(-16~-20)', '원달러환율수익률표준편차(-6~-10)', '런던 코코아 선물 과거 데이터(-6~-10)', '미국_원면(-1~-5)', '탄소배출권(-1~-5)', '미국_소맥(-11~-15)', '현미(-16~-20)', 'putcall(-20)', '원목(-6~-10)', '미국_설탕(-11~-15)']
# PC59 상위 기여 변수: ['런던_커피(-1~-5)', '천연가스(-1~-5)', '돈육(-6~-10)', '아연(-16~-20)', '코스닥수익률표준편차(-6~-10)', '백금(-6~-10)', '천연가스(-16~-20)', '원달러환율수익률표준편차(-11~-15)', '납(-1~-5)', '아연(-11~-15)']
# PC60 상위 기여 변수: ['납(-6~-10)', '육우(-11~-15)', '알루미늄(-11~-15)', '오렌지주스(-6~-10)', '납(-16~-20)', '미국_원면(-6~-10)', '미국_원면(-11~-15)', '미국_대두유(-6~-10)', '코스피수익률표준편차(-11~-15)', '현미(-11~-15)']
# PC61 상위 기여 변수: ['미국_소맥(-16~-20)', '오렌지주스(-1~-5)', '납(-6~-10)', '1~5일 수익률 표준편차', '알루미늄(-1~-5)', '백금(-11~-15)', '코스닥수익률표준편차(-16~-20)', '미국_대두박(-6~-10)', '귀리(-11~-15)', '육우(-1~-5)']
# PC62 상위 기여 변수: ['1~5일 수익률 표준편차', '생우(-6~-10)', '원목(-11~-15)', '납(-16~-20)', '돈육(-1~-5)', '코스피수익률표준편차(-16~-20)', '미국_대두유(-16~-20)', '돈육(-6~-10)', '원달러환율수익률표준편차(-1~-5)', '미국_설탕(-1~-5)']
# Top 20 important features:
# 시장금리국고채3년                    0.100187
# 미국_원면(-1~-5)          0.043369
# 알루미늄(-6~-10)           0.037424
# 런던_가스오일(-1~-5)      0.033804
# 나스닥수익률표준편차(-11~-15)          0.031918
# 나스닥수익률표준편차(-1~-5)            0.029746
# 미국_소맥(-16~-20)         0.026803
# 알루미늄(-1~-5)            0.024978
# 미국_원면(-11~-15)        0.021518
# 알루미늄(-16~-20)          0.020588
# 런던_가스오일(-11~-15)    0.019674
# 나스닥수익률표준편차(-16~-20)          0.019649
# 런던_소맥(-16~-20)        0.018609
# 런던_가스오일(-6~-10)     0.016679
# 미국_소맥(-1~-5)           0.016258
# 런던_소맥(-11~-15)        0.014936
# 미국_대두유(-16~-20)        0.014674
# 런던_소맥(-1~-5)          0.014621
# VIXCLS                       0.014157
# 미국_원면(-16~-20)        0.013880
# dtype: float64
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       143
#            1       1.00      0.71      0.83        17
#
#     accuracy                           0.97       160
#    macro avg       0.98      0.85      0.91       160
# weighted avg       0.97      0.97      0.97       160

# %%
pd.set_option('display.max_columns', None)  # 출력할 최대 컬럼 수 제한 해제
profile
# Out:
#          1~5일 수익률 표준편차  6~10일 수익률 표준편차  11~15일 수익률 표준편차  16~20일 수익률 표준편차  \
# cluster
# 0             0.241906        0.051096         0.042448         0.043041
# 1             0.196264        0.046266         0.038988         0.045988
#
#          kospi200(-20)  nasdaq(-20)  putcall(-20)     VIXCLS  \
# cluster
# 0             0.025453     0.014323      0.011352  17.918176
# 1             0.091008    -0.013097      0.019654  28.000714
#
#          미국10년물국채금리수익률(-20)  시장금리국고채3년  환율변동률(-20)  코스피변동률(-20)  코스닥변동률(-20)  \
# cluster
# 0                  0.020505   1.669851    0.001181     0.003123    -0.000574
# 1                  0.025280   3.330714    0.006049    -0.015015    -0.024912
#
#          런던_가스오일(-1~-5)  런던_가스오일(-6~-10)  \
# cluster
# 0                       0.013588                  0.015709
# 1                       0.029653                  0.033858
#
#          런던_가스오일(-11~-15)  런던_가스오일(-16~-20)  \
# cluster
# 0                         0.014389                   0.013266
# 1                         0.033058                   0.026507
#
#          난방유(-1~-5)  난방유(-6~-10)  난방유(-11~-15)  \
# cluster
# 0               0.013466          0.015014           0.014357
# 1               0.026056          0.027137           0.023219
#
#          난방유(-16~-20)  탄소배출권(-1~-5)  탄소배출권(-6~-10)  \
# cluster
# 0                 0.013797              0.018369               0.020350
# 1                 0.022065              0.023984               0.025525
#
#          탄소배출권(-11~-15)  탄소배출권(-16~-20)  브렌트유(-1~-5)  \
# cluster
# 0                      0.019385                0.017887          0.014653
# 1                      0.021757                0.022942          0.023961
#
#          브렌트유(-6~-10)  브렌트유(-11~-15)  브렌트유(-16~-20)  \
# cluster
# 0                 0.016432            0.015291            0.015117
# 1                 0.026887            0.019395            0.020729
#
#          가솔린(-1~-5)  가솔린(-6~-10)  가솔린(-11~-15)  \
# cluster
# 0               0.015919          0.016958           0.015962
# 1               0.025033          0.027324           0.022256
#
#          가솔린(-16~-20)  천연가스(-1~-5)  천연가스(-6~-10)  \
# cluster
# 0                 0.016029           0.023922            0.025766
# 1                 0.022698           0.037004            0.043699
#
#          천연가스(-11~-15)  천연가스(-16~-20)  WTI유(-1~-5)  \
# cluster
# 0                   0.022591             0.021848      0.015949
# 1                   0.040917             0.036081      0.026595
#
#          WTI유(-6~-10)  WTI유(-11~-15)  WTI유(-16~-20)  금(-1~-5)  \
# cluster
# 0             0.017687        0.016478        0.015487    0.005966
# 1             0.029738        0.022435        0.024177    0.007934
#
#          금(-6~-10)  금(-11~-15)  금(-16~-20)  은(-1~-5)  은(-6~-10)  \
# cluster
# 0           0.006505      0.006604      0.005895    0.011119     0.012108
# 1           0.008525      0.008919      0.007240    0.017701     0.016133
#
#          은(-11~-15)  은(-16~-20)  백금(-1~-5)  백금(-6~-10)  \
# cluster
# 0            0.011817      0.010795       0.010772        0.012054
# 1            0.017386      0.015475       0.016954        0.018666
#
#          백금(-11~-15)  백금(-16~-20)  주석(-1~-5)  주석(-6~-10)  \
# cluster
# 0               0.011110         0.010937      0.008324       0.009868
# 1               0.017223         0.015122      0.018281       0.020310
#
#          주석(-11~-15)  주석(-16~-20)  납(-1~-5)  납(-6~-10)  \
# cluster
# 0              0.008908        0.007965    0.010012     0.011006
# 1              0.018247        0.015401    0.012776     0.014607
#
#          납(-11~-15)  납(-16~-20)  아연(-1~-5)  아연(-6~-10)  \
# cluster
# 0            0.010456      0.009887      0.010653       0.012205
# 1            0.014469      0.013282      0.016316       0.016541
#
#          아연(-11~-15)  아연(-16~-20)  알루미늄(-1~-5)  \
# cluster
# 0              0.010922        0.010919           0.007659
# 1              0.016142        0.013456           0.015200
#
#          알루미늄(-6~-10)  알루미늄(-11~-15)  알루미늄(-16~-20)  \
# cluster
# 0                  0.008911             0.008520             0.007983
# 1                  0.017810             0.014983             0.014787
#
#          니켈(-1~-5)  니켈(-6~-10)  니켈(-11~-15)  니켈(-16~-20)  \
# cluster
# 0            0.012592       0.014681        0.014318        0.013309
# 1            0.035139       0.027986        0.027903        0.028993
#
#          구리_영국(-1~-5)  구리_영국(-6~-10)  구리_영국(-11~-15)  \
# cluster
# 0                  0.008415             0.009768              0.009029
# 1                  0.011494             0.013051              0.012472
#
#          구리_영국(-16~-20)  구리_미국(-1~-5)  구리_미국(-6~-10)  \
# cluster
# 0                    0.008702           0.009145            0.010472
# 1                    0.012972           0.013049            0.015198
#
#          구리_미국(-11~-15)  구리_미국(-16~-20)  미국_커피(-1~-5)  \
# cluster
# 0                   0.009964             0.009650           0.014134
# 1                   0.013907             0.013298           0.019506
#
#          미국_커피(-6~-10)  미국_커피(-11~-15)  미국_커피(-16~-20)  \
# cluster
# 0                  0.015799             0.014820             0.014208
# 1                  0.020748             0.018536             0.018079
#
#          미국_원면(-1~-5)  미국_원면(-6~-10)  미국_원면(-11~-15)  \
# cluster
# 0                   0.009866              0.011126               0.010470
# 1                   0.018467              0.022829               0.021868
#
#          미국_원면(-16~-20)  현미(-1~-5)  현미(-6~-10)  현미(-11~-15)  \
# cluster
# 0                      0.01016      0.008263       0.008669        0.008145
# 1                      0.02159      0.007657       0.009948        0.007024
#
#          현미(-16~-20)  돈육(-1~-5)  돈육(-6~-10)  돈육(-11~-15)  \
# cluster
# 0              0.008329       0.016108        0.019104         0.016790
# 1              0.008748       0.013466        0.015341         0.012536
#
#          돈육(-16~-20)  미국_옥수수(-1~-5)  미국_옥수수(-6~-10)  \
# cluster
# 0               0.014769              0.010567               0.011927
# 1               0.014178              0.013045               0.014686
#
#          미국_옥수수(-11~-15)  미국_옥수수(-16~-20)  런던_소맥(-1~-5)  \
# cluster
# 0                      0.011234                0.010226             0.007469
# 1                      0.013601                0.013225             0.014469
#
#          런던_소맥(-6~-10)  런던_소맥(-11~-15)  런던_소맥(-16~-20)  \
# cluster
# 0                    0.008138               0.007398               0.007220
# 1                    0.018057               0.014421               0.017864
#
#          미국_소맥(-1~-5)  미국_소맥(-6~-10)  미국_소맥(-11~-15)  \
# cluster
# 0                  0.012804             0.014649              0.013268
# 1                  0.022271             0.026088              0.020170
#
#          미국_소맥(-16~-20)  오렌지주스(-1~-5)  오렌지주스(-6~-10)  \
# cluster
# 0                    0.012532            0.013583             0.015246
# 1                    0.024612            0.022054             0.021215
#
#          오렌지주스(-11~-15)  오렌지주스(-16~-20)  원목(-1~-5)  \
# cluster
# 0                    0.013819              0.013406       0.019042
# 1                    0.018647              0.019724       0.024369
#
#          원목(-6~-10)  원목(-11~-15)  원목(-16~-20)  \
# cluster
# 0              0.021551         0.021089         0.018518
# 1              0.027511         0.021494         0.023600
#
#          미국_대두유(-1~-5)  미국_대두유(-6~-10)  미국_대두유(-11~-15)  \
# cluster
# 0                   0.009673              0.010988               0.010207
# 1                   0.017543              0.018918               0.015485
#
#          미국_대두유(-16~-20)  미국_설탕(-1~-5)  미국_설탕(-6~-10)  \
# cluster
# 0                     0.009891             0.012560              0.014109
# 1                     0.016625             0.011018              0.011270
#
#          미국_설탕(-11~-15)  미국_설탕(-16~-20)  미국_대두박(-1~-5)  \
# cluster
# 0                     0.013275               0.012783              0.009381
# 1                     0.011559               0.011235              0.012339
#
#          미국_대두박(-6~-10)  미국_대두박(-11~-15)  \
# cluster
# 0                     0.010935                0.009716
# 1                     0.014702                0.013784
#
#          미국_대두박(-16~-20)  생우(-1~-5)  생우(-6~-10)  생우(-11~-15)  \
# cluster
# 0                      0.008888      0.007367       0.008074        0.008037
# 1                      0.012177      0.006609       0.007173        0.006647
#
#          생우(-16~-20)  런던_커피(-1~-5)  런던_커피(-6~-10)  \
# cluster
# 0              0.007725            0.009680             0.011264
# 1              0.007195            0.009649             0.011721
#
#          런던_커피(-11~-15)  런던_커피(-16~-20)  런던_설탕(-1~-5)  \
# cluster
# 0                    0.010121              0.009546              0.010101
# 1                    0.009529              0.009184              0.011725
#
#          런던_설탕(-6~-10)  런던_설탕(-11~-15)  \
# cluster
# 0                     0.011961                0.011167
# 1                     0.013143                0.013918
#
#          런던_설탕(-16~-20)  귀리(-1~-5)  귀리(-6~-10)  귀리(-11~-15)  \
# cluster
# 0                      0.010134     0.013765      0.015373       0.015086
# 1                      0.010976     0.018737      0.022600       0.024243
#
#          귀리(-16~-20)  런던 코코아 선물 과거 데이터(-1~-5)  런던 코코아 선물 과거 데이터(-6~-10)  \
# cluster
# 0             0.014105                 0.010164                  0.011951
# 1             0.022239                 0.010799                  0.012073
#
#          런던 코코아 선물 과거 데이터(-11~-15)  런던 코코아 선물 과거 데이터(-16~-20)  육우(-1~-5)  \
# cluster
# 0                         0.010893                   0.009507      0.007415
# 1                         0.010589                   0.009298      0.008307
#
#          육우(-6~-10)  육우(-11~-15)  육우(-16~-20)  미국_대두(-1~-5)  \
# cluster
# 0             0.008557        0.008000        0.007403           0.008134
# 1             0.011048        0.008654        0.008708           0.013249
#
#          미국_대두(-6~-10)  미국_대두(-11~-15)  미국_대두(-16~-20)  \
# cluster
# 0                  0.009293             0.008462             0.008112
# 1                  0.013136             0.011834             0.012480
#
#          코스닥수익률표준편차(-1~-5)  코스닥수익률표준편차(-6~-10)  코스닥수익률표준편차(-11~-15)  \
# cluster
# 0                 0.011503            0.010956             0.011174
# 1                 0.017072            0.017423             0.017985
#
#          코스닥수익률표준편차(-16~-20)  코스피수익률표준편차(-1~-5)  코스피수익률표준편차(-6~-10)  \
# cluster
# 0                   0.011124           0.008147            0.007900
# 1                   0.018112           0.011688            0.011634
#
#          코스피수익률표준편차(-11~-15)  코스피수익률표준편차(-16~-20)  나스닥수익률표준편차(-1~-5)  \
# cluster
# 0                   0.008345             0.008397           0.010285
# 1                   0.011944             0.011978           0.022885
#
#          나스닥수익률표준편차(-6~-10)  나스닥수익률표준편차(-11~-15)  나스닥수익률표준편차(-16~-20)  \
# cluster
# 0                  0.010044             0.010114             0.010075
# 1                  0.020993             0.020620             0.018962
#
#          원달러환율수익률표준편차(-1~-5)  원달러환율수익률표준편차(-6~-10)  원달러환율수익률표준편차(-11~-15)  \
# cluster
# 0                   0.004747              0.004797               0.004847
# 1                   0.007241              0.006581               0.006654
#
#          원달러환율수익률표준편차(-16~-20)
# cluster
# 0                     0.004625
# 1                     0.006184

# %% [markdown]
# ## 다중공선성 제외 -> 클러스터링 -> RF

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 1. Load and preprocess multi data
multi = pd.read_csv('../data/주가수익률/주가수익률_base.csv')
multi = multi.drop(columns=['상장일', 'stock_code']).dropna().reset_index(drop=True)

# 2. Check and remove multicollinearity via VIF
def calculate_vif(df, thresh=10.0):
    variables = df.select_dtypes(include=[np.number]).columns.tolist()
    while True:
        vif = pd.Series(
            [variance_inflation_factor(df[variables].values, i) for i in range(len(variables))],
            index=variables
        )
        max_vif = vif.max()
        if max_vif > thresh:
            drop_var = vif.idxmax()
            print(f"Dropping '{drop_var}' with VIF={max_vif:.2f}")
            variables.remove(drop_var)
        else:
            break
    return df[variables]

X_numeric = multi.drop(columns=['회사명'])
X_vif = calculate_vif(X_numeric, thresh=10.0)
print("Remaining features after VIF filtering:", X_vif.columns.tolist())

# 3. Merge 경기국면 into multi
sm = pd.read_csv('../data/주가수익률/주가수익률_동행순환변동치_smooth.csv')
sm = sm[['회사명', '경기국면']]
multi = multi.merge(sm, on='회사명')

# 4. Clustering (include 경기국면 as independent variable)
le_phase = LabelEncoder()
multi['경기국면_encoded'] = le_phase.fit_transform(multi['경기국면'])

# Prepare clustering features
X_cluster = pd.concat([X_vif, multi[['경기국면_encoded']]], axis=1)

# Scale features
scaler = StandardScaler()
X_cluster_scaled = scaler.fit_transform(X_cluster)

# Silhouette analysis
range_n_clusters = range(2, 11)
silhouette_avgs = []
for n_clusters in range_n_clusters:
    km = KMeans(n_clusters=n_clusters, random_state=42)
    labels = km.fit_predict(X_cluster_scaled)
    score = silhouette_score(X_cluster_scaled, labels)
    silhouette_avgs.append(score)
    print(f"n_clusters={n_clusters}, silhouette score={score:.3f}")

plt.figure()
plt.plot(list(range_n_clusters), silhouette_avgs, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Average silhouette score')
plt.title('Silhouette Analysis')
plt.show()

# Determine best cluster count
best_n = range_n_clusters[np.argmax(silhouette_avgs)]
print(f"Best number of clusters: {best_n}")

# Detailed silhouette plot for best_n
km = KMeans(n_clusters=best_n, random_state=42)
cluster_labels = km.fit_predict(X_cluster_scaled)
sil_values = silhouette_samples(X_cluster_scaled, cluster_labels)

plt.figure(figsize=(8, 6))
plt.xlim([-0.1, 1])
plt.ylim([0, len(X_cluster_scaled) + (best_n + 1) * 10])
y_lower = 10
for i in range(best_n):
    ith_sil_values = np.sort(sil_values[cluster_labels == i])
    size_cluster = ith_sil_values.shape[0]
    y_upper = y_lower + size_cluster
    plt.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_sil_values)
    y_lower = y_upper + 10

plt.title(f"Silhouette Plot for {best_n} Clusters")
plt.xlabel("Silhouette Coefficient Values")
plt.ylabel("Cluster Label")
plt.show()

# Assign cluster labels
multi['cluster'] = cluster_labels

# 5. Random Forest to predict clusters
features = X_cluster.columns.tolist()
X = scaler.fit_transform(multi[features])
y = multi['cluster']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train RF
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# Confusion matrix & classification report
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
target_names = [str(c) for c in sorted(np.unique(y))]
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=target_names))

# Feature importances
feat_importances = pd.Series(rf.feature_importances_, index=features)
feat_importances.index = feat_importances.index.str.replace('경기국면_encoded', '경기국면')
feat_importances = feat_importances.sort_values(ascending=False)
print("Feature Importances:\n", feat_importances)

# Sorted feature list
sorted_features = feat_importances.index.tolist()
print("Features sorted by importance:", sorted_features)

# Plot importances
plt.figure(figsize=(10, 6))
plt.barh(feat_importances.index, feat_importances.values)
plt.xlabel('Importance')
plt.title('Random Forest Feature Importances for Cluster Prediction')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Dropping '브렌트유(-11~-15)' with VIF=67.86
# Dropping '구리_영국(-6~-10)' with VIF=63.67
# Dropping '브렌트유(-1~-5)' with VIF=59.52
# Dropping '브렌트유(-6~-10)' with VIF=58.48
# Dropping '브렌트유(-16~-20)' with VIF=58.41
# Dropping 'VIXCLS' with VIF=52.69
# Dropping '구리_영국(-11~-15)' with VIF=51.48
# Dropping '시장금리국고채3년' with VIF=44.89
# Dropping '구리_영국(-1~-5)' with VIF=43.49
# Dropping '난방유(-6~-10)' with VIF=38.44
# Dropping '난방유(-11~-15)' with VIF=38.06
# Dropping '구리_영국(-16~-20)' with VIF=36.92
# Dropping '난방유(-1~-5)' with VIF=28.77
# Dropping 'WTI유(-16~-20)' with VIF=26.01
# Dropping '코스피수익률표준편차(-6~-10)' with VIF=22.99
# Dropping '미국_대두(-11~-15)' with VIF=21.17
# Dropping '미국_대두(-6~-10)' with VIF=21.00
# Dropping '코스피수익률표준편차(-1~-5)' with VIF=19.64
# Dropping '코스피수익률표준편차(-11~-15)' with VIF=18.96
# Dropping '코스피수익률표준편차(-16~-20)' with VIF=18.95
# Dropping '미국_대두(-16~-20)' with VIF=18.21
# Dropping '난방유(-16~-20)' with VIF=18.04
# Dropping '금(-11~-15)' with VIF=17.09
# Dropping 'WTI유(-6~-10)' with VIF=16.86
# Dropping '금(-6~-10)' with VIF=16.71
# Dropping '미국_대두(-1~-5)' with VIF=15.91
# Dropping 'WTI유(-11~-15)' with VIF=15.47
# Dropping '미국_소맥(-6~-10)' with VIF=14.85
# Dropping '미국_설탕(-6~-10)' with VIF=14.77
# Dropping '나스닥수익률표준편차(-6~-10)' with VIF=14.73
# Dropping '아연(-6~-10)' with VIF=14.36
# Dropping '백금(-6~-10)' with VIF=14.13
# Dropping 'WTI유(-1~-5)' with VIF=13.62
# Dropping '미국_대두유(-6~-10)' with VIF=13.24
# Dropping '나스닥수익률표준편차(-11~-15)' with VIF=13.14
# Dropping '나스닥수익률표준편차(-1~-5)' with VIF=12.95
# Dropping '알루미늄(-6~-10)' with VIF=12.89
# Dropping '백금(-11~-15)' with VIF=12.84
# Dropping '금(-1~-5)' with VIF=12.72
# Dropping '원달러환율수익률표준편차(-6~-10)' with VIF=12.67
# Dropping '미국_대두유(-11~-15)' with VIF=12.59
# Dropping '백금(-1~-5)' with VIF=12.49
# Dropping '금(-16~-20)' with VIF=12.18
# Dropping '미국_소맥(-11~-15)' with VIF=11.95
# Dropping '미국_설탕(-16~-20)' with VIF=11.75
# Dropping '미국_소맥(-1~-5)' with VIF=11.57
# Dropping '런던_커피(-6~-10)' with VIF=11.54
# Dropping '런던_가스오일(-6~-10)' with VIF=11.34
# Dropping '원달러환율수익률표준편차(-16~-20)' with VIF=11.21
# Dropping '미국_소맥(-16~-20)' with VIF=10.99
# Dropping '백금(-16~-20)' with VIF=10.96
# Dropping '원달러환율수익률표준편차(-11~-15)' with VIF=10.63
# Dropping '미국_대두유(-16~-20)' with VIF=10.47
# Dropping '나스닥수익률표준편차(-16~-20)' with VIF=10.40
# Dropping '미국_대두박(-11~-15)' with VIF=10.37
# Dropping '구리_미국(-11~-15)' with VIF=10.30
# Remaining features after VIF filtering: ['1~5일 수익률 표준편차', '6~10일 수익률 표준편차', '11~15일 수익률 표준편차', '16~20일 수익률 표준편차', 'kospi200(-20)', 'nasdaq(-20)', 'putcall(-20)', '미국10년물국채금리수익률(-20)', '환율변동률(-20)', '코스피변동률(-20)', '코스닥변동률(-20)', '런던_가스오일(-1~-5)', '런던_가스오일(-11~-15)', '런던_가스오일(-16~-20)', '탄소배출권(-1~-5)', '탄소배출권(-6~-10)', '탄소배출권(-11~-15)', '탄소배출권(-16~-20)', '가솔린(-1~-5)', '가솔린(-6~-10)', '가솔린(-11~-15)', '가솔린(-16~-20)', '천연가스(-1~-5)', '천연가스(-6~-10)', '천연가스(-11~-15)', '천연가스(-16~-20)', '은(-1~-5)', '은(-6~-10)', '은(-11~-15)', '은(-16~-20)', '주석(-1~-5)', '주석(-6~-10)', '주석(-11~-15)', '주석(-16~-20)', '납(-1~-5)', '납(-6~-10)', '납(-11~-15)', '납(-16~-20)', '아연(-1~-5)', '아연(-11~-15)', '아연(-16~-20)', '알루미늄(-1~-5)', '알루미늄(-11~-15)', '알루미늄(-16~-20)', '니켈(-1~-5)', '니켈(-6~-10)', '니켈(-11~-15)', '니켈(-16~-20)', '구리_미국(-1~-5)', '구리_미국(-6~-10)', '구리_미국(-16~-20)', '미국_커피(-1~-5)', '미국_커피(-6~-10)', '미국_커피(-11~-15)', '미국_커피(-16~-20)', '미국_원면(-1~-5)', '미국_원면(-6~-10)', '미국_원면(-11~-15)', '미국_원면(-16~-20)', '현미(-1~-5)', '현미(-6~-10)', '현미(-11~-15)', '현미(-16~-20)', '돈육(-1~-5)', '돈육(-6~-10)', '돈육(-11~-15)', '돈육(-16~-20)', '미국_옥수수(-1~-5)', '미국_옥수수(-6~-10)', '미국_옥수수(-11~-15)', '미국_옥수수(-16~-20)', '런던_소맥(-1~-5)', '런던_소맥(-6~-10)', '런던_소맥(-11~-15)', '런던_소맥(-16~-20)', '오렌지주스(-1~-5)', '오렌지주스(-6~-10)', '오렌지주스(-11~-15)', '오렌지주스(-16~-20)', '원목(-1~-5)', '원목(-6~-10)', '원목(-11~-15)', '원목(-16~-20)', '미국_대두유(-1~-5)', '미국_설탕(-1~-5)', '미국_설탕(-11~-15)', '미국_대두박(-1~-5)', '미국_대두박(-6~-10)', '미국_대두박(-16~-20)', '생우(-1~-5)', '생우(-6~-10)', '생우(-11~-15)', '생우(-16~-20)', '런던_커피(-1~-5)', '런던_커피(-11~-15)', '런던_커피(-16~-20)', '런던_설탕(-1~-5)', '런던_설탕(-6~-10)', '런던_설탕(-11~-15)', '런던_설탕(-16~-20)', '귀리(-1~-5)', '귀리(-6~-10)', '귀리(-11~-15)', '귀리(-16~-20)', '런던 코코아 선물 과거 데이터(-1~-5)', '런던 코코아 선물 과거 데이터(-6~-10)', '런던 코코아 선물 과거 데이터(-11~-15)', '런던 코코아 선물 과거 데이터(-16~-20)', '육우(-1~-5)', '육우(-6~-10)', '육우(-11~-15)', '육우(-16~-20)', '코스닥수익률표준편차(-1~-5)', '코스닥수익률표준편차(-6~-10)', '코스닥수익률표준편차(-11~-15)', '코스닥수익률표준편차(-16~-20)', '원달러환율수익률표준편차(-1~-5)']
# n_clusters=2, silhouette score=0.197
# n_clusters=3, silhouette score=0.138
# n_clusters=4, silhouette score=0.050
# n_clusters=5, silhouette score=0.026
# n_clusters=6, silhouette score=0.017
# n_clusters=7, silhouette score=0.017
# n_clusters=8, silhouette score=0.019
# n_clusters=9, silhouette score=0.022
# n_clusters=10, silhouette score=0.025
# Best number of clusters: 2
# Confusion Matrix:
#  [[139   0]
#  [  7  14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       139
#            1       1.00      0.67      0.80        21
#
#     accuracy                           0.96       160
#    macro avg       0.98      0.83      0.89       160
# weighted avg       0.96      0.96      0.95       160
#
# Feature Importances:
#  미국_원면(-6~-10)       0.043783
# 런던_소맥(-6~-10)       0.043083
# 런던_소맥(-16~-20)      0.042002
# 런던_소맥(-1~-5)        0.041215
# 미국_원면(-1~-5)        0.035676
#                              ...
# 탄소배출권(-11~-15)     0.000813
# 런던 코코아 선물 과거 데이터(-1~-5)    0.000770
# 탄소배출권(-6~-10)      0.000713
# 미국_옥수수(-11~-15)     0.000621
# 런던_커피(-16~-20)       0.000569
# Length: 118, dtype: float64
